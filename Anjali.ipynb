# %% [markdown]
# Observations: Median sold price Vs Median rent price : All years have clear relationship as the price go up rent go up.
# Median sold price vs no of rent listing: No of rent listings are higher for lesser median sold price and vice versa.
# Median sold price vs No of Auction sold: No of auction sold is higer for lesser median sold price and vice versa.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from scipy.stats import linregress

# %%
#load csv into dataframe
csv_2019  = "Resources/yearly_data_clean_2019.csv"
csv_2020  = "Resources/yearly_data_clean_2020.csv"
csv_2021  = "Resources/yearly_data_clean_2021.csv"
df_realestate_2019 = pd.read_csv(csv_2019)
df_realestate_2020 = pd.read_csv(csv_2020)
df_realestate_2021 = pd.read_csv(csv_2021)
df_realestate_2019.head()
# Out:
#    Postcode        Suburb  ID_Domain  medianSoldPrice  numberSold  \
# 0      3067    Abbotsford        627         990000.0        57.0
# 1      3040    Aberfeldie        647        1368000.0       244.0
# 2      3042  Airport West        757         953000.0        74.0
# 3      3021     Albanvale        787         596000.0       348.0
# 4      3206   Albert Park        797        2575000.0        55.0
#
#    highestSoldPrice  lowestSoldPrice  5thPercentileSoldPrice  \
# 0         2425000.0         370000.0                661000.0
# 1         8000000.0         297000.0                480000.0
# 2         1500000.0         480000.0                610000.0
# 3         1400000.0         300000.0                410000.0
# 4         8600000.0         735000.0               1353000.0
#
#    25thPercentileSoldPrice  75thPercentileSoldPrice  ...  \
# 0                 808000.0                1445000.0  ...
# 1                 876000.0                1820000.0  ...
# 2                 800000.0                1100000.0  ...
# 3                 510000.0                 650000.0  ...
# 4                1990000.0                3650000.0  ...
#
#    medianSaleListingPrice  numberSaleListing  highestSaleListingPrice  \
# 0               1150000.0               71.0                2573000.0
# 1               1300000.0              285.0                8000000.0
# 2                953000.0               98.0                1470000.0
# 3                599000.0              532.0                2500000.0
# 4               2425000.0               52.0               13000000.0
#
#    lowestSaleListingPrice  auctionNumberAuctioned  auctionNumberSold  \
# 0                115000.0                    50.0               26.0
# 1                280000.0                   182.0               94.0
# 2                500000.0                    62.0               24.0
# 3                 60000.0                   132.0               41.0
# 4                315000.0                    37.0               17.0
#
#    medianRentListingPrice  numberRentListing  highestRentListingPrice  \
# 0                   645.0              150.0                   1250.0
# 1                   525.0              373.0                   1400.0
# 2                   475.0              125.0                   1350.0
# 3                   360.0              521.0                   1647.0
# 4                   840.0               95.0                   2000.0
#
#    lowestRentListingPrice
# 0                   400.0
# 1                   250.0
# 2                   260.0
# 3                   190.0
# 4                   350.0
#
# [5 rows x 21 columns]

# %%
# Define x, y values and lables
title = "Q6: Median Sold Price vs. Median Rent Price(2019)"
x_values = df_realestate_2019['medianSoldPrice'].astype('float')
y_values = df_realestate_2019['medianRentListingPrice'].astype('float')
x_label = "Median Sold Price"
y_label = "Median Rent Price"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.0x + 240.21
# The r-value is: 0.8489568101467605

# %%
# Define x, y values and lables
title = "Q7: Median Sold Price vs. No of Rent Listing(2019)"
x_values = df_realestate_2019['medianSoldPrice'].astype('float')
y_values = df_realestate_2019['numberRentListing'].astype('float')
x_label = "Median Sold Price"
y_label = "No of Rent Listing"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.0x + 218.19
# The r-value is: 0.005952142562970703

# %%
# Define x, y values and lables
title = "Q6: Median Sold Price vs. No of auction sold(2019)"
x_values = df_realestate_2019['medianSoldPrice'].astype('float')
y_values = df_realestate_2019['auctionNumberSold'].astype('float')
x_label = "Median Sold Price"
y_label = "No of auction sold"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.0x + 17.54
# The r-value is: 0.05249998953006646

# %%
# Define x, y values and lables
title = "Q6: Median Sold Price vs. Median Rent Price(2020)"
x_values = df_realestate_2020['medianSoldPrice'].astype('float')
y_values = df_realestate_2020['medianRentListingPrice'].astype('float')
x_label = "Median Sold Price"
y_label = "Median Rent Price"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.0x + 285.79
# The r-value is: 0.8277099837440647

# %%
# Define x, y values and lables
title = "Q7: Median Sold Price vs. No of Rent Listing(2020)"
x_values = df_realestate_2020['medianSoldPrice'].astype('float')
y_values = df_realestate_2020['numberRentListing'].astype('float')
x_label = "Median Sold Price"
y_label = "No of Rent Listing"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.0x + 245.48
# The r-value is: 0.008906599455448742

# %%
# Define x, y values and lables
title = "Q6: Median Sold Price vs. No of auction sold(2020)"
x_values = df_realestate_2020['medianSoldPrice'].astype('float')
y_values = df_realestate_2020['auctionNumberSold'].astype('float')
x_label = "Median Sold Price"
y_label = "No of auction sold"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.0x + 28.97
# The r-value is: 0.02484864269501859

# %%
# Define x, y values and lables
title = "Q6: Median Sold Price vs. Median Rent Price(2021)"
x_values = df_realestate_2021['medianSoldPrice'].astype('float')
y_values = df_realestate_2021['medianRentListingPrice'].astype('float')
x_label = "Median Sold Price"
y_label = "Median Rent Price"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.0x + 289.47
# The r-value is: 0.7963149218997483

# %%
# Define x, y values and lables
title = "Q7: Median Sold Price vs. No of Rent Listing(2021)"
x_values = df_realestate_2021['medianSoldPrice'].astype('float')
y_values = df_realestate_2021['numberRentListing'].astype('float')
x_label = "Median Sold Price"
y_label = "No of Rent Listing"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.0x + 233.07
# The r-value is: 0.006385111076991047

# %%
# Define x, y values and lables
title = "Q6: Median Sold Price vs. No of auction sold(2021)"
x_values = df_realestate_2021['medianSoldPrice'].astype('float')
y_values = df_realestate_2021['auctionNumberSold'].astype('float')
x_label = "Median Sold Price"
y_label = "No of auction sold"

# Scatter plot 
plt.scatter(x_values,y_values,edgecolors="black",facecolors="lightblue")
# Axis and title
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)
# formatting
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig(f"output_data/{title}.png")
plt.show()

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
#plt.annotate(line_eq,(1.0,600.0),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")

# Label plot
plt.title(title)
plt.xlabel(x_label)
plt.ylabel(y_label)

# Print r square value
print(line_eq)
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.0x + 23.93
# The r-value is: 0.015644916762797067
